# %%
import os
os.chdir("..")

# %%
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from string import ascii_uppercase
import numpy as np
import pandas as pd


def example_scatter_plot(num_cats=6):
    for i in range(num_cats):
        cat = ascii_uppercase[i]
        x = np.random.random(100)
        y = np.random.random(100) + i
        plt.scatter(x, y, marker='o', label=cat)
    plt.legend(loc='upper left')


def example_bar_plot(num_cats=6):
    bar_width = 1 / num_cats + 1
    for i in range(num_cats):
        cat = ascii_uppercase[i]
        x = np.arange(11) + 5 * i
        y = np.array([0, 1, 2, 3, 4, 5, 4, 3, 2, 1, 0]) + np.random.random(1)
        plt.bar(x, y, label=cat, width=bar_width)
    plt.legend(loc='upper left')

# %%
example_scatter_plot()

# %%
example_bar_plot()

# %%
from pyplot_themes import rcmod, themes, palettes

# %%
sns.palplot(palettes.Colorblind.colors)

# %%
themes.theme_minimal()

# %%
example_scatter_plot()

# %%
example_bar_plot()

# %%
themes.theme_tableau()

# %%
example_scatter_plot()

# %%
example_bar_plot()

# %%
sns.palplot(palettes.Solarized.dark)

# %%
themes.theme_solarized(scheme="dark")

# %%
example_scatter_plot()

# %%
example_bar_plot()

# %%
sns.palplot(palettes.Solarized.light)

# %%
themes.theme_solarized(scheme="light")

# %%
example_scatter_plot()

# %%
sns.palplot(palettes.PaulTolColorSchemes.colors)

# %%
themes.theme_paul_tol(reverse=False)

# %%
example_scatter_plot(num_cats=9)

# %%
example_bar_plot(num_cats=9)

# %%
themes.theme_paul_tol(reverse=True)

# %%
example_scatter_plot(num_cats=9)

# %%
example_bar_plot(num_cats=9)

# %%
sns.palplot(palettes.Few.light)
sns.palplot(palettes.Few.medium)
sns.palplot(palettes.Few.dark)

# %%
themes.theme_few(scheme="light")
example_scatter_plot()

# %%
example_bar_plot()

# %%
themes.theme_few(scheme="medium")
example_scatter_plot()

# %%
themes.theme_few(scheme="dark")
example_bar_plot()

# %%
themes.theme_fivethirtyeight()

# %%
example_bar_plot()

# %%
example_scatter_plot()

# %%
themes.theme_ggplot2()

# %%
example_scatter_plot()

# %%
example_bar_plot()

# %%
themes.theme_ggplot2(palette=palettes.PaulTolColorSchemes.colors)
example_bar_plot(num_cats=10)

# %%
themes.theme_ggplot2(palette=palettes.FiveThirtyEight.colors)
example_bar_plot()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'tableau-colorblind10']

# %%
themes.theme_solarized_light2()
example_scatter_plot()

# %%
themes.theme_solarized_light2(grid=False)
example_scatter_plot()

# %%
from pyplot_themes import rcmod, themes, palettes

# %%
sns.palplot([c['color'] for c in plt.rcParams["axes.prop_cycle"]])

# %%
# themes.theme_bmh(palette=[c['color'] for c in plt.rcParams["axes.prop_cycle"]])
plt.style.use("bmh")
example_scatter_plot()

# %%
plt.rcParams["axes.prop_cycle"]
# Out:
# cycler('color', ['#348ABD', '#A60628', '#7A68A6', '#467821', '#D55E00', '#CC79A7', '#56B4E9', '#009E73', '#F0E442', '#0072B2'])

# %%
themes.theme_bmh()
example_scatter_plot()

# %%
themes.theme_bmh(palettes)
example_scatter_plot()
